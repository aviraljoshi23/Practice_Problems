# %% [markdown]
# <a href="https://colab.research.google.com/github/aviraljoshi23/Practice_Problems/blob/main/Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words='''In the areas of Natural Language Processing we come across situation where two or more words have a common root.
 For example, the three words - agreed, agreeing and agreeable have the same root word agree. A search involving any of these words should treat
  them as the same word which is the root word. So it becomes essential to link all the words into their root word. 
  The NLTK library has methods to do this linking and give the output showing the root word.'''

list1=nltk.word_tokenize(words)

# %%
print(list1)
# Out:
# ['In', 'the', 'areas', 'of', 'Natural', 'Language', 'Processing', 'we', 'come', 'across', 'situation', 'where', 'two', 'or', 'more', 'words', 'have', 'a', 'common', 'root', '.', 'For', 'example', ',', 'the', 'three', 'words', '-', 'agreed', ',', 'agreeing', 'and', 'agreeable', 'have', 'the', 'same', 'root', 'word', 'agree', '.', 'A', 'search', 'involving', 'any', 'of', 'these', 'words', 'should', 'treat', 'them', 'as', 'the', 'same', 'word', 'which', 'is', 'the', 'root', 'word', '.', 'So', 'it', 'becomes', 'essential', 'to', 'link', 'all', 'the', 'words', 'into', 'their', 'root', 'word', '.', 'The', 'NLTK', 'library', 'has', 'methods', 'to', 'do', 'this', 'linking', 'and', 'give', 'the', 'output', 'showing', 'the', 'root', 'word', '.']

# %%
Lemmatization=WordNetLemmatizer()

# %%
lemmatization_of_word=' '.join([Lemmatization.lemmatize(words) for words in list1]) 
print(lemmatization_of_word)
# Out:
# In the area of Natural Language Processing we come across situation where two or more word have a common root . For example , the three word - agreed , agreeing and agreeable have the same root word agree . A search involving any of these word should treat them a the same word which is the root word . So it becomes essential to link all the word into their root word . The NLTK library ha method to do this linking and give the output showing the root word .
