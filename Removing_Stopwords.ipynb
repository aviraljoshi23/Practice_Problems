# %% [markdown]
# <a href="https://colab.research.google.com/github/aviraljoshi23/Practice_Problems/blob/main/Removing_Stopwords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

example_sent = """Most of us use lies from time to time to avoid difficult situations and hide our feelings or intentions. 
       You will feel better about yourself if you are honest and open. ... Others will be able to trust you and trust is the basis for all relationships.."""

stop_words = set(stopwords.words('english')) 

word_tokens = word_tokenize(example_sent) 

filtered_sentence = [w for w in word_tokens if not w in stop_words] 

filtered_sentence = [] 

for w in word_tokens: 
	if w not in stop_words: 
		filtered_sentence.append(w) 

print(word_tokens) 
print(filtered_sentence)
# Out:
# ['Most', 'of', 'us', 'use', 'lies', 'from', 'time', 'to', 'time', 'to', 'avoid', 'difficult', 'situations', 'and', 'hide', 'our', 'feelings', 'or', 'intentions', '.', 'You', 'will', 'feel', 'better', 'about', 'yourself', 'if', 'you', 'are', 'honest', 'and', 'open', '.', '...', 'Others', 'will', 'be', 'able', 'to', 'trust', 'you', 'and', 'trust', 'is', 'the', 'basis', 'for', 'all', 'relationships..']
# ['Most', 'us', 'use', 'lies', 'time', 'time', 'avoid', 'difficult', 'situations', 'hide', 'feelings', 'intentions', '.', 'You', 'feel', 'better', 'honest', 'open', '.', '...', 'Others', 'able', 'trust', 'trust', 'basis', 'relationships..']
